# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lthendral10/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#I chose the Content Performance Prediction lane because it focuses on identifying webpages that may perform better in search results. This project can help prioritize which pages should be improved first, making SEO efforts more efficient.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#Can we predict which webpages are likely to have better search performance using the available dataset?

### Decision
#Decide which webpages should be optimized first.

### Action
#SEO teams can improve pages predicted to have lower performance by updating content, keywords, and page structure.

### Cost of a Wrong Recommendation
#If the prediction is wrong, time and resources may be spent on the wrong pages while important pages are ignored. This can reduce the effectiveness of SEO improvements.

### Why Machine Learning?
#Machine learning can identify patterns in historical data and support better decision-making.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !git clone https://github.com/lthendral10/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# !ls data/raw
import pandas as pd

# Load the dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Basic information
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

# Display column names
print("\nColumns:")
print(df.columns.tolist())

# Summary statistics
print("\nSummary Statistics:")
print(df.describe(include="all"))
## Quick Look at the Data

#The starter dataset contains **30,000 content pages** and **44 features**, providing a large amount of information for analysis. The average search volume is **158.88**, and the average search position is **16.34**. These values suggest there is enough variation in the data to explore patterns that can support content optimization decisions over the next seven weeks.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

print("\nAverage Search Volume:", round(df["search_volume"].mean(), 2))
print("Average Position:", round(df["avg_position"].mean(), 2))
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 119 (delta 34), reused 94 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.85 MiB | 11.67 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship
# content_refresh_anonymized.csv
# Number of rows: 30000
# Number of columns: 44
#
# Columns:
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## Careful Words

#This project provides decision-support by identifying patterns observed in historical data. The results can help prioritize webpages for optimization, but they do not prove that updating a page will guarantee better search rankings. The analysis is based on observed relationships and should be combined with human judgment when making decisions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
