# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lthendral10/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## My Lane as an ML Task
#
# I chose the Content Performance Prediction lane. This can be framed as a **classification** task, where the goal is to identify which content pages should be prioritized for optimization based on their historical SEO and engagement data.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Target or Proxy
#
# The target is whether a content page should be prioritized for optimization. As a proxy, I can use metrics such as trend direction, search performance, or engagement indicators from the dataset to identify pages that may benefit from updates.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Success Metric
#
# A useful success metric is classification accuracy along with precision and recall. These metrics help evaluate how well the model identifies pages that should be prioritized for optimization.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !git clone https://github.com/lthendral10/flyrank-ml-internship.git
# %cd flyrank-ml-internship
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("One row represents one content page.\n")

print(df.head())

print("\nDataset Shape:", df.shape)
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 134 (delta 45), reused 92 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (134/134), 1.85 MiB | 7.75 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /content/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship
# One row represents one content page.
#
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
# ...

# %% [markdown]
# ## Unit of Analysis
#
# Each row in the dataset represents one content page. Each page includes SEO, search performance, traffic, engagement, and content-related features that can be used for analysis.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Why ML Beats a Fixed Rule
#
# A fixed rule cannot easily combine many features such as search volume, CTR, average position, engagement, and content age. Machine learning can learn patterns from multiple variables simultaneously and provide better decision support for prioritizing content updates.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
